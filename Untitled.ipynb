# %%
import cv2
import pytesseract
from PIL import Image
#tessdata_dir_config = r--tessdata-dir "/usr/local/Cellar/tesseract/4.1.1/share/tessdata"
def ocr_core(image):
    text = pytesseract.image_to_string(silent, 'storysquadset')
    # text = ocr(img,'storysquad','opencv/storysquad.traineddata')
    return text

img = cv2.imread('/Users/victoriadebebe/Documents/GitHub/Lambda_Labs/story-squad-ds-a/Practice Handwriting NB/MW-tester.jpg')
photo = cv2.imshow("Trial",img)
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

def remove_noise(image):
    return cv2.medianBlur(image, 5)

def thresh(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

gray = get_grayscale(img)
thresh = thresh(gray)
silent = remove_noise(thresh)

print(ocr_core(silent))
print(gray)
print(photo)
# Out:
# . | ‘§ § A: Naa |
# F.n's L...tHe Leagu¢ Tryouts
#
# The El:ppecloa|l deflecls off of a goo! post
# With a resounding THUNK! Blbies drift fojwrds
# +he Surface as Finn lets owt a Sigh, though
#
# . lhe Still looks QS dctirmned GS ever.
#
# “Ont loS+ thy } Finn! C60.ch Ulrch calls oot
# .From his Dpot On +he Sideline. He'd Seen O
#
# .lox OF 9pp'eS (fowrfeen | to be ext ) 90 +hrowah
# tryouts Yoday } +h Clipboord O-f the RO. UrcA'n'S
# 5.9 held o. list OF thir names ond O. {ally
#
# OF the 900-15 +hey'd Made. s...
# Finn. ge (Coach [Arn 08 (6nFidRot . nod Gnd...
# gets back n positron. Canter Field, he con
#
# . 9Qe the ball ply, o.li9nd _ With +e Soa! In _ _ _
# is oind's ye j he Knows eXachy how to PMe(l _
# Fhe. bal With the bak of he cf, ...
# _.. Oe Mofe _ deep Inhale . bRfore __finn Chorges_ _. . _
# Forward, . putting He Fw] Pore. of his i! into _
# the Sid oe the bl. That lawached. orb . Sajls _ __. _
# hg 4 he ake, 1 Ae _ geadiR's_ -hqad,.. _ond____
# loo the 0 le hin Alo :_ 4 El if! I Made Ri
#
# a +6 he crowd. The qs of Ae
# agplawe, on'y. Gilbe+ Scams +o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fon Ches
#
# B
# a: (oohaS 3: 9S QS). il pe
# ; +h QeeK'.
#
#
#
# [[166 166 165 ... 136 136 136]
#  [166 166 165 ... 139 139 139]
#  [166 166 165 ... 143 143 143]
#  ...
#  [ 50  50  49 ... 104 104 104]
#  [ 50  50  49 ... 102 102 102]
#  [ 50  50  49 ... 100 100 100]]
# None
